# %% [markdown]
# <a href="https://colab.research.google.com/github/Qitaa/PCVK_Genap_2023/blob/main/Week_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/Images/kitten.jpeg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/Images/kitten.jpeg',cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello Gaiz',org=(10,500),fontFace=font,fontScale=2,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %%
#2 (Green-Blue)

img_red = cv.imread('/content/drive/MyDrive/Images/kitten.jpeg',cv.IMREAD_GRAYSCALE)
plt.imshow(img_red, cmap='GnBu')

# %%
#2 (Red-blue)

img_red = cv.imread('/content/drive/MyDrive/Images/kitten.jpeg',cv.IMREAD_GRAYSCALE)
plt.imshow(img_red, cmap='RdYlBu')

# %%
#3
img_size = img[20:115,25:120]
plt.imshow(img_size)

# %%
img_green = cv.imread('/content/drive/MyDrive/Images/kitten.jpeg',cv.IMREAD_GRAYSCALE)
plt.imshow(img_green[5:30], cmap='Reds')

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
imgku2 = imgku
imgku3 = cv.cvtColor(imgku,cv.COLOR_BGR2RGB)
cv.rectangle(imgku3,pt1=(550,70),pt2=(1200,650),color=(192,142,199),thickness=25)
cv.circle(imgku3,center=(900,350),radius=250,color=(255,0,0),thickness=18)
plt.imshow(imgku3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-1569007fa31a> in <module>
# ----> 1 imgku2 = imgku
#       2 imgku3 = cv.cvtColor(imgku,cv.COLOR_BGR2RGB)
#       3 cv.rectangle(imgku3,pt1=(550,70),pt2=(1200,650),color=(192,142,199),thickness=25)
#       4 cv.circle(imgku3,center=(900,350),radius=250,color=(255,0,0),thickness=18)
#       5 plt.imshow(imgku3)
#
# NameError: name 'imgku' is not defined
